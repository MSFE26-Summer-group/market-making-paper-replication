# %%
import rdata

parsed = rdata.parser.parse_file("../data/btc_usdt_lob_snapshot_2022-10-20.rds")
df = rdata.conversion.convert(parsed)

print(type(df))
print(df.shape if hasattr(df, "shape") else df)
